# %%
import pandas as pd

# %pip install openpyxl

# %%
df=pd.read_csv('cot_40_metr.csv')

# %%
df
# Out:
#     Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 0              0             0           485         492
# 1              1             1           817         828
# 2              2             2            30          33
# 3              3             3           551         560
# 4              4             4            96         100
# 5              5             5           244         249
# 6              6             6           559         568
# 7              7             7           352         359
# 8              8             8           465         472
# 9              9             9           544         552
# 10            10            10           448         455
# 11            11            11           254         259
# 12            12            12           250         255
# 13            13            13            65          69
# 14            14            14           669         679
# 15            15            15           215         220
# 16            16            16            39          42
# 17            17            17           192         197
# 18            18            18            86          90
# 19            19            19           490         497
# 20            20            20           640         650
# 21            21            21           196         201
# 22            22            22           209         214
# 23            23            23           212         217
# 24            24            24           739         750
# 25            25            25           275         280
# 26            26            26           120         125
# 27            27            27           292         298
# 28            28            28           139         144
# 29            29            29           291         297
# 30            30            30           837         848
# 31            31            31            63          67
# 32            32            32           675         686
# 33            33            33            66          70
# 34            34            34           534         542
# 35            35            35           519         527
# 36            36            36           334         341
# 37            37            37           328         335
# 38            38            38           239         244
# 39            39            39           417         424
#
#                                                     q  \
# 0   Автор детективов Иэн Рэнкин увлекается неким з...
# 1   Некоторые виды мух называют путниками из-за их...
# 2   Хави Повес активно продвигает концепцию плоско...
# 3   Борющаяся с музыкальными корпорациями группа C...
# 4   Голландский шахматист Мануэль Босбом выиграл с...
# 5   Во время холодной войны американку ДжУдит КОпл...
# 6   В произведении Романа Сефа стадо ИХ исчезает н...
# 7   Однажды корабль «Баттерфляй» сильно пострадал ...
# 8   Журналистка и феминистка Рут Хейл жила в начал...
# 9   Рядом с одной ветеринарной клиникой растёт опр...
# 10  Учёные опасаются, что у планеты Земля в будуще...
# 11  В начале и конце испанской газеты «El Mundo» [...
# 12  Из-за увлечения людей здоровым образом жизни с...
# 13  В шуточном рассказе Харта Померанца маленький ...
# 14  Подростков, которые стремятся освободиться от ...
# 15  На необычном фото СИнди КЭрол девушка держит н...
# 16  В одной ганской пословице говорится, что бессм...
# 17  По статистике, большинство выпускников российс...
# 18  Согласно Википедии, ОНА - это «символ эпохи вз...
# 19  Клиенту, который заплатил мало, ИКСЫ могли нап...
# 20  Рассказывая о том, как сушить дрова, Ларс Митт...
# 21  Одна социальная реклама призывала регулярно по...
# 22  Толерантную Польшу шестнадцатого века называли...
# 23  По одной примете, лучше не есть РЫБ в новогодн...
# 24  В честь какого писателя названа российская ком...
# 25  Первого апреля 2018 года Европейская организац...
# 26  Идея об атомах пришла Демокриту в голову, когд...
# 27  В терминологии NASA [нáса] ОНИ называются «оде...
# 28  В 1981 году американское представительство ком...
# 29  В произведении Яна Сáшина сказка стала причино...
# 30  Альберто Анджела пишет, что если проследить пе...
# 31  В эпосе "Махабхарата" принцесса Дамаянти должн...
# 32  В статье о турецких мастерицах говорится, что ...
# 33  Про легендарного правителя Уэльса Кадваллона г...
# 34  Согласно шутке, первым глобалистом был человек...
# 35  Крупные города, вокруг которых в семнадцатом в...
# 36  Во время протестов в Бретани в XVII веке крест...
# 37  Исидор Севильский называл ЕЁ единственной четв...
# 38  В эмиграции поэт Георгий АдамОвич устроился ра...
# 39  14 ноября 1963 года на севере Атлантического о...
#
#                                                     a  \
# 0   собирать пазл, собирать мозаику, складывать па...
# 1                       спутниками, спутники, спутник
# 2                                астронавт, космонавт
# 3                                      троянский конь
# 4                                         дырка, дыра
# 5                                             роман,
# 6                                             барашки
# 7                                               кит,
# 8                                     девичья фамилия
# 9                                                 кот
# 10                                             кольца
# 11                                         матрёшка,
# 12             количество килокалорий в одной булочке
# 13                            Исаака Ньютона, Ньютона
# 14                                          мёда, мёд
# 15                                           лестница
# 16                                ганские пословицы,
# 17                                     корочки, корки
# 18                                          Википедия
# 19                                          трубочист
# 20                                       Джерри и Том
# 21                                          девять, 9
# 22                                             костёр
# 23  раки, ракообразные, крабы, рак, ракообразный, ...
# 24                                          Грибоедов
# 25                       Шалтай-Болтай, Humpty Dumpty
# 26                         Исааку Ньютону, по фамилии
# 27                               подгузники, памперсы
# 28                                              Марио
# 29                                                под
# 30                                             монета
# 31                                               тень
# 32                                            дневник
# 33                              Юрий Долгорукий, Юрий
# 34                          ФернАн МагеллАн, Магеллан
# 35                                     Солнце, солнце
# 36                     Красная шапочка, Красная шапка
# 37                                       летучая мышь
# 38                                            СизИф,
# 39                                     Огненная Земля
#
#                       predict  f1_score  exact_match  \
# 0       Раскладывать пасьянс.  0.000000            0
# 1                  расстоянии  0.000000            0
# 2                   Космонавт  0.666667            0
# 3                  Дон Кихот.  0.000000            0
# 4                    Надпись.  0.000000            0
# 5                      Роман.  1.000000            1
# 6                     Овечки.  0.000000            0
# 7                 Баттерфляй.  0.000000            0
# 8             Девичья фамилия  1.000000            1
# 9                      собака  0.000000            0
# 10                     Кольца  1.000000            1
# 11                    Складка  0.000000            0
# 12               калорийность  0.000000            0
# 13                   Ньютона.  0.500000            0
# 14                    Крылья.  0.000000            0
# 15                     Крыса.  0.000000            0
# 16                   Истории.  0.000000            0
# 17                  «корочки»  0.000000            0
# 18                     Книга.  0.000000            0
# 19                     Маляр.  0.000000            0
# 20  Белоснежка и семь гномов.  0.285714            0
# 21                        911  0.000000            0
# 22                      Папы.  0.000000            0
# 23                      Раки.  0.285714            0
# 24                  Астафьев.  0.000000            0
# 25       В честь Питера Пэна.  0.000000            0
# 26                     яблоко  0.000000            0
# 27                 Скафандры.  0.000000            0
# 28               Стив Возняк.  0.000000            0
# 29                      «Бы».  0.000000            0
# 30                   История.  0.000000            0
# 31                      Тень.  1.000000            1
# 32                   Дневник.  1.000000            1
# 33                     Ричард  0.000000            0
# 34             Васко да Гама.  0.000000            0
# 35                    Сердце.  0.000000            0
# 36           «Красная шапка».  0.000000            0
# 37               летучая мышь  1.000000            1
# 38                     Сизиф.  1.000000            1
# 39           **Остров огня**.  0.000000            0
#
#                                       answer_checking  correct  \
# 0   #НЕВЕРНО\n\nИэн Рэнкин увлекается собиранием п...    False
# 1   #НЕВЕРНО.\n\nКоманда ответила на вопрос неполн...    False
# 2   #ВЕРНО\nОтвет команды «Космонавт» можно зачест...     True
# 3   #НЕВЕРНО\n\nОтвет команды нельзя зачесть, поск...    False
# 4   #НЕВЕРНО\n\nОтвет команды не подходит, посколь...    False
# 5   #ВЕРНО\nРассуждения:\nОтвет команды «Роман» мо...     True
# 6   #НЕВЕРНО\n\nОтвет команды не подходит, потому ...    False
# 7   #НЕВЕРНО\n\nРассуждения: в вопросе говорится, ...    False
# 8   #ВЕРНО\n\nОтвет команды совпадает с правильным...     True
# 9   #НЕВЕРНО\n\n**Рассуждения**: на логотипе ветер...    False
# 10  #ВЕРНО\nРассуждения: ответ команды совпадает с...     True
# 11  #НЕВЕРНО\n\nПравильный ответ «матрёшка» не мож...    False
# 12  #ВЕРНО\n\nРассуждения: ответ команды можно зач...     True
# 13  #ВЕРНО\n\nОтвет команды совпадает с правильным...     True
# 14  #НЕВЕРНО\n\nОтвет команды не подходит по смысл...    False
# 15  #НЕВЕРНО\n\nОтвет команды не подходит по смысл...    False
# 16  #НЕВЕРНО\n\nВ ганской пословице речь идёт о то...    False
# 17  #ВЕРНО\n\nОтвет команды совпадает с правильным...     True
# 18  #НЕВЕРНО\n\nОтвет команды не подходит под опис...    False
# 19  #НЕВЕРНО\n\nОтвет команды «маляр» не подходит ...    False
# 20  #НЕВЕРНО\n\nКоманда дала неверный ответ, так к...    False
# 21  #НЕВЕРНО\n\nКоманда дала ответ 911, который не...    False
# 22  #НЕВЕРНО\nРассуждения: в вопросе идёт речь о н...    False
# 23  #ВЕРНО\n\nОтвет команды можно зачесть, так как...     True
# 24  #НЕВЕРНО\n\nКомпания, продающая сушёные лисичк...    False
# 25  #НЕВЕРНО\n\nЧастица получила название «Шалтай-...    False
# 26  #НЕВЕРНО\nРассуждения: Демокрит — греческий фи...    False
# 27  #НЕВЕРНО\nРассуждения: подгузники и скафандры ...    False
# 28  #НЕВЕРНО\n\nОтвет команды не подходит под вопр...    False
# 29  #НЕВЕРНО\n\nОтвет команды не подходит по смысл...    False
# 30  #НЕВЕРНО\n\nОтвет команды не подходит по смысл...    False
# 31  #ВЕРНО\nРассуждения: Ответ команды «Тень» явля...     True
# 32  #ВЕРНО\nРассуждения: в статье о турецких масте...     True
# 33  #НЕВЕРНО\n\nРассуждения: прозвище Кадваллона —...    False
# 34  #НЕВЕРНО\nРассуждения: Согласно шутке, первым ...    False
# 35  #НЕВЕРНО\n\nОтвет команды «Сердце» не подходит...    False
# 36  #ВЕРНО\n\nОтвет команды «Красная шапка» можно ...     True
# 37  #ВЕРНО\nРассуждения: оба ответа — «летучая мыш...     True
# 38  #ВЕРНО\n\nОтвет команды «Сизиф» можно зачесть,...     True
# 39  #НЕВЕРНО\n\nКоманда дала ответ «Остров огня», ...    False
#
#                                              thoughts  \
# 0   **1–2.** Автор детективов Иэн Рэнкин увлекаетс...
# 1   **Шаг 1.** В вопросе есть такие детали и подск...
# 2   Конечно, я могу помочь вам с этим вопросом. Во...
# 3   Конечно, я могу попытаться найти ответ на этот...
# 4   Хорошо, давайте попробуем ответить на этот воп...
# 5   1 - 2) В этом вопросе могут быть важны следующ...
# 6   1 - 2) В вопросе упоминается стадо, которое ис...
# 7   **1–2.** В вопросе есть такие детали:\n* кораб...
# 8   Конечно, я могу помочь вам с вопросом о Рут Хе...
# 9   1 - 2) В вопросе упоминается определённое круп...
# 10  1 - 2) В вопросе есть такая важная деталь, как...
# 11  Конечно, я могу помочь вам найти ответ на вопр...
# 12  **1–2.** В вопросе идёт речь о сети пекарен, к...
# 13  1. **Важные детали вопроса и потенциальные под...
# 14  1 - 2) В вопросе упоминаются подростки, которы...
# 15  Хорошо, давайте попробуем найти ответ на этот ...
# 16  1 - 2) В ганской пословице говорится о том, чт...
# 17  1 - 2) В этом вопросе могут быть важны следующ...
# 18  Хорошо, я попробую найти ответ на этот вопрос,...
# 19  **1–2.** В вопросе говорится о клиенте, которы...
# 20  1 - 2) В вопросе говорится о сушке дров и о то...
# 21  1–2) В вопросе упоминается социальная реклама,...
# 22  1 - 2) В вопросе упоминается толерантная Польш...
# 23  1. **Важные детали и потенциальные подсказки.*...
# 24  1 - 2) В вопросе упоминается российская компан...
# 25  1-2) В вопросе есть важная деталь — дата откры...
# 26  **1–2.** В вопросе говорится об идее атомов, к...
# 27  **1–2.** В вопросе есть намёк на терминологию ...
# 28  **1-2)** В вопросе есть несколько важных детал...
# 29  1. В вопросе есть намёк на то, что у школьника...
# 30  1 - 2) Я вижу, в вопросе неспроста могут быть:...
# 31  **1–2.** В этом вопросе я вижу следующие детал...
# 32  1 - 2) В вопросе упоминаются турецкие мастериц...
# 33  1 - 2) Кадваллон — легендарный правитель Уэльс...
# 34  **1 - 2)** В вопросе есть подсказка — Португал...
# 35  1 - 2) Историк Фернан Бродель изучал развитие ...
# 36  **1–2.** В вопросе есть несколько деталей, кот...
# 37  **Исидор Севильский называл ЕЁ единственной че...
# 38  **Вопрос: В эмиграции поэт Георгий Адамович ус...
# 39  1 - 2) Новый остров Сюртсей назван в честь пер...
#
#                                          answer_cot  \
# 0                             Сортировка информации
# 1                                             Охота
# 2                                     Исследователь
# 3                                    Давид и Голиаф
# 4                                              Рука
# 5                                            Роман.
# 6                                           Барашки
# 7                                          Капитан.
# 8                                    Личная свобода
# 9                                             БЕЛКА
# 10                                        АСТЕРОИДЫ
# 11                                     Многотиражка
# 12                                     Калорийность
# 13  АльбертЭйнштейн опроверг теорию относительности
# 14                                           Крылья
# 15                                     Конструкция.
# 16                           Пословицы и поговорки.
# 17                                 Навыки и умения.
# 18                                       Библиотека
# 19                                        Вредитель
# 20                                      кошкакорова
# 21                                      Дваразавгод
# 22                                          вешалки
# 23                                             Торт
# 24                                    МихаилПришвин
# 25                                             ЛЕГО
# 26                                 Обычный предмет.
# 27                              Подушки или матрасы
# 28                                     ЯмаутиХироси
# 29                                              УХО
# 30                                           Монета
# 31                                           Отслед
# 32                                        портфолио
# 33                             ВильгельмЗавоеватель
# 34                                         Магеллан
# 35                                         Центрами
# 36                                       Жёлтыйцвет
# 37                                    Летучая мышь.
# 38                                             Поэт
# 39                                    Остров вулкан
#
#                                      answer_cot_check  correct_cot
# 0   #ВЕРНО\n\nОтвет команды «сортировка информации...         True
# 1   Рассуждения:\n\nКоманда дала ответ «Охота», ко...        False
# 2   #НЕВЕРНО\n\nОтвет команды не подходит под конт...        False
# 3   #НЕВЕРНО\n\nВ ответе команды «Давид и Голиаф» ...        False
# 4   #НЕВЕРНО\n\nВ вопросе спрашивают про «ещё одну...        False
# 5   #ВЕРНО\n\nРассуждения:\nОтвет команды соответс...         True
# 6   #ВЕРНО\n\nОтвет команды соответствует правильн...         True
# 7   Рассуждения:\n\nВ вопросе говорится о корабле ...        False
# 8   #НЕВЕРНО\n\nЛичная свобода — это состояние чел...        False
# 9   #НЕВЕРНО\n\nВ ответе команды упоминается белка...        False
# 10  Рассуждения:\n\nВопрос касается возможного поя...        False
# 11  Рассуждения:\nВ контексте вопроса важно, что г...        False
# 12  #ВЕРНО\n\nОтвет команды «Калорийность» можно з...         True
# 13  Рассуждения:\n\nОтвет команды не подходит к во...        False
# 14  Рассуждения:\n\nПерсонаж Джона Грина сравнивае...        False
# 15  #НЕВЕРНО\n\nКонструкция — это общее название р...        False
# 16  **Рассуждения**:\n\nВ ганской пословице говори...        False
# 17  Рассуждения:\n\nПравильный ответ «корочки, кор...        False
# 18  Рассуждения:\n\nКоманда дала ответ «Библиотека...         True
# 19  #НЕВЕРНО\n\nОтвет команды «вредитель» не подхо...        False
# 20  **Рассуждения**:\n\nВ вопросе идёт речь о прав...        False
# 21  Рассуждения:\n\nВ этом вопросе речь идёт об из...        False
# 22  Рассуждения:\n\nВ вопросе спрашивают, без чего...        False
# 23  #НЕВЕРНО\n\nВ контексте вопроса спрашивается, ...        False
# 24  #НЕВЕРНО\n\nВ вопросе спрашивают, в честь како...        False
# 25  Рассуждения:\n\nВопрос касается открытия новой...        False
# 26  Рассуждения:\n\nПравильный ответ указывает на ...        False
# 27  #НЕВЕРНО\n\nХотя в вопросе не уточняется, для ...        False
# 28  #НЕВЕРНО\n\nВ вопросе спрашивают имя итальянск...        False
# 29  **Рассуждения:**\n\nПравильный ответ — «под». ...        False
# 30  **Рассуждения.**\n\nВопрос касается того, что ...        False
# 31  Рассуждения:\n\nОтвет команды «Отслед» не соот...        False
# 32  #НЕВЕРНО\n\nВ статье о турецких мастерицах гов...        False
# 33  Рассуждения:\n\nВопрос касается прозвища Кадва...        False
# 34  #ВЕРНО\n\nВ вопросе спрашивают, кто был первым...         True
# 35  #НЕВЕРНО\n\nВ вопросе требуется одно слово — о...        False
# 36  Рассуждения:\n\nВопрос касается восстания «Кра...        False
# 37  #ВЕРНО\n\nКоманда дала верный ответ, который с...         True
# 38  Рассуждения:\nВопрос касается сравнения поэта ...        False
# 39  Рассуждения:\n\nВопрос касается происхождения ...        False

# %%
# from sklearn.model_selection import train_test_split

# %%
# train, test = train_test_split(df,test_size=400, random_state=42)

# %%
# base_string='Вы участвуете в викторине “Что? Где? Когда?”. Внимательно прочитайте вопрос и ответьте на него. Обратите внимание на формат ответа: если он не указан в вопросе, то запишите только слово или фразу, отвечающую на вопрос, никаких дополнительных рассуждений приводить не нужно. Вопрос:'

# %% [markdown]
# # Инференс

# %%
# pip install --upgrade pip

# %%
# pip install wheel #### Нужно для pip install yandexgpt-python

# %%
# pip install yandexgpt-python
from env_vars import *

# %%
from yandex_gpt import YandexGPTConfigManagerForAPIKey

# Initialize the configuration manager with model type, catalog ID, and API key
config_manager = YandexGPTConfigManagerForAPIKey(
    model_type="yandexgpt",
    catalog_id=CATALOGUE_ID,
    api_key=API_KEY
)

# %%
from yandex_gpt import YandexGPT

# Initialize YandexGPT with a configuration manager
yandex_gpt = YandexGPT(config_manager=config_manager)

# %%
from time import sleep
def query_gpt(row, prompt=base_string):
    completion = yandex_gpt.get_sync_completion(messages=[{'role': 'user', 'text': prompt+row['q'] + ' Ответ:' }])
    sleep(1)
    return completion

# %%
test
# Out:
#      Unnamed: 0                                                  q  \
# 485         492  Автор детективов Иэн Рэнкин увлекается неким з...
# 817         828  Некоторые виды мух называют путниками из-за их...
# 30           33  Хави Повес активно продвигает концепцию плоско...
# 551         560  Борющаяся с музыкальными корпорациями группа C...
# 96          100  Голландский шахматист Мануэль Босбом выиграл с...
# ..          ...                                                ...
# 289         294  Василий Рóзанов писал, что Наталья Нóрдман пог...
# 238         243  Математик семнадцатого века Джон ВАллис активн...
# 0             0  В одном из эпизодов мультфильма Криса Батлера ...
# 832         843  В стихотворении под названием «ОН» Дэвид Лоуре...
# 409         416  «Сначала паруса, а потом корпус корабля». Это ...
#
#                                                      a
# 485  собирать пазл, собирать мозаику, складывать па...
# 817                      спутниками, спутники, спутник
# 30                                астронавт, космонавт
# 551                                     троянский конь
# 96                                         дырка, дыра
# ..                                                 ...
# 289                                            пылесос
# 238  курица, куриная лапа, лапа курицы, лапка куриц...
# 0                                        сэр, сир, sir
# 832                             комары, комар, комарик
# 409  шарообразность Земли, Что Земля шар, а также Ч...
#
# [400 rows x 3 columns]

# %%
test['predict'] = test.apply(query_gpt, axis=1)

# %%
test.to_csv('test_results.csv')

# %%
len(test)
# Out:
# 400

# %%
test= df

# %%
test
# Out:
#     Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 0              0             0           485         492
# 1              1             1           817         828
# 2              2             2            30          33
# 3              3             3           551         560
# 4              4             4            96         100
# 5              5             5           244         249
# 6              6             6           559         568
# 7              7             7           352         359
# 8              8             8           465         472
# 9              9             9           544         552
# 10            10            10           448         455
# 11            11            11           254         259
# 12            12            12           250         255
# 13            13            13            65          69
# 14            14            14           669         679
# 15            15            15           215         220
# 16            16            16            39          42
# 17            17            17           192         197
# 18            18            18            86          90
# 19            19            19           490         497
# 20            20            20           640         650
# 21            21            21           196         201
# 22            22            22           209         214
# 23            23            23           212         217
# 24            24            24           739         750
# 25            25            25           275         280
# 26            26            26           120         125
# 27            27            27           292         298
# 28            28            28           139         144
# 29            29            29           291         297
# 30            30            30           837         848
# 31            31            31            63          67
# 32            32            32           675         686
# 33            33            33            66          70
# 34            34            34           534         542
# 35            35            35           519         527
# 36            36            36           334         341
# 37            37            37           328         335
# 38            38            38           239         244
# 39            39            39           417         424
#
#                                                     q  \
# 0   Автор детективов Иэн Рэнкин увлекается неким з...
# 1   Некоторые виды мух называют путниками из-за их...
# 2   Хави Повес активно продвигает концепцию плоско...
# 3   Борющаяся с музыкальными корпорациями группа C...
# 4   Голландский шахматист Мануэль Босбом выиграл с...
# 5   Во время холодной войны американку ДжУдит КОпл...
# 6   В произведении Романа Сефа стадо ИХ исчезает н...
# 7   Однажды корабль «Баттерфляй» сильно пострадал ...
# 8   Журналистка и феминистка Рут Хейл жила в начал...
# 9   Рядом с одной ветеринарной клиникой растёт опр...
# 10  Учёные опасаются, что у планеты Земля в будуще...
# 11  В начале и конце испанской газеты «El Mundo» [...
# 12  Из-за увлечения людей здоровым образом жизни с...
# 13  В шуточном рассказе Харта Померанца маленький ...
# 14  Подростков, которые стремятся освободиться от ...
# 15  На необычном фото СИнди КЭрол девушка держит н...
# 16  В одной ганской пословице говорится, что бессм...
# 17  По статистике, большинство выпускников российс...
# 18  Согласно Википедии, ОНА - это «символ эпохи вз...
# 19  Клиенту, который заплатил мало, ИКСЫ могли нап...
# 20  Рассказывая о том, как сушить дрова, Ларс Митт...
# 21  Одна социальная реклама призывала регулярно по...
# 22  Толерантную Польшу шестнадцатого века называли...
# 23  По одной примете, лучше не есть РЫБ в новогодн...
# 24  В честь какого писателя названа российская ком...
# 25  Первого апреля 2018 года Европейская организац...
# 26  Идея об атомах пришла Демокриту в голову, когд...
# 27  В терминологии NASA [нáса] ОНИ называются «оде...
# 28  В 1981 году американское представительство ком...
# 29  В произведении Яна Сáшина сказка стала причино...
# 30  Альберто Анджела пишет, что если проследить пе...
# 31  В эпосе "Махабхарата" принцесса Дамаянти должн...
# 32  В статье о турецких мастерицах говорится, что ...
# 33  Про легендарного правителя Уэльса Кадваллона г...
# 34  Согласно шутке, первым глобалистом был человек...
# 35  Крупные города, вокруг которых в семнадцатом в...
# 36  Во время протестов в Бретани в XVII веке крест...
# 37  Исидор Севильский называл ЕЁ единственной четв...
# 38  В эмиграции поэт Георгий АдамОвич устроился ра...
# 39  14 ноября 1963 года на севере Атлантического о...
#
#                                                     a  \
# 0   собирать пазл, собирать мозаику, складывать па...
# 1                       спутниками, спутники, спутник
# 2                                астронавт, космонавт
# 3                                      троянский конь
# 4                                         дырка, дыра
# 5                                             роман,
# 6                                             барашки
# 7                                               кит,
# 8                                     девичья фамилия
# 9                                                 кот
# 10                                             кольца
# 11                                         матрёшка,
# 12             количество килокалорий в одной булочке
# 13                            Исаака Ньютона, Ньютона
# 14                                          мёда, мёд
# 15                                           лестница
# 16                                ганские пословицы,
# 17                                     корочки, корки
# 18                                          Википедия
# 19                                          трубочист
# 20                                       Джерри и Том
# 21                                          девять, 9
# 22                                             костёр
# 23  раки, ракообразные, крабы, рак, ракообразный, ...
# 24                                          Грибоедов
# 25                       Шалтай-Болтай, Humpty Dumpty
# 26                         Исааку Ньютону, по фамилии
# 27                               подгузники, памперсы
# 28                                              Марио
# 29                                                под
# 30                                             монета
# 31                                               тень
# 32                                            дневник
# 33                              Юрий Долгорукий, Юрий
# 34                          ФернАн МагеллАн, Магеллан
# 35                                     Солнце, солнце
# 36                     Красная шапочка, Красная шапка
# 37                                       летучая мышь
# 38                                            СизИф,
# 39                                     Огненная Земля
#
#                       predict  f1_score  exact_match  \
# 0       Раскладывать пасьянс.  0.000000            0
# 1                  расстоянии  0.000000            0
# 2                   Космонавт  0.666667            0
# 3                  Дон Кихот.  0.000000            0
# 4                    Надпись.  0.000000            0
# 5                      Роман.  1.000000            1
# 6                     Овечки.  0.000000            0
# 7                 Баттерфляй.  0.000000            0
# 8             Девичья фамилия  1.000000            1
# 9                      собака  0.000000            0
# 10                     Кольца  1.000000            1
# 11                    Складка  0.000000            0
# 12               калорийность  0.000000            0
# 13                   Ньютона.  0.500000            0
# 14                    Крылья.  0.000000            0
# 15                     Крыса.  0.000000            0
# 16                   Истории.  0.000000            0
# 17                  «корочки»  0.000000            0
# 18                     Книга.  0.000000            0
# 19                     Маляр.  0.000000            0
# 20  Белоснежка и семь гномов.  0.285714            0
# 21                        911  0.000000            0
# 22                      Папы.  0.000000            0
# 23                      Раки.  0.285714            0
# 24                  Астафьев.  0.000000            0
# 25       В честь Питера Пэна.  0.000000            0
# 26                     яблоко  0.000000            0
# 27                 Скафандры.  0.000000            0
# 28               Стив Возняк.  0.000000            0
# 29                      «Бы».  0.000000            0
# 30                   История.  0.000000            0
# 31                      Тень.  1.000000            1
# 32                   Дневник.  1.000000            1
# 33                     Ричард  0.000000            0
# 34             Васко да Гама.  0.000000            0
# 35                    Сердце.  0.000000            0
# 36           «Красная шапка».  0.000000            0
# 37               летучая мышь  1.000000            1
# 38                     Сизиф.  1.000000            1
# 39           **Остров огня**.  0.000000            0
#
#                                       answer_checking  correct  \
# 0   #НЕВЕРНО\n\nИэн Рэнкин увлекается собиранием п...    False
# 1   #НЕВЕРНО.\n\nКоманда ответила на вопрос неполн...    False
# 2   #ВЕРНО\nОтвет команды «Космонавт» можно зачест...     True
# 3   #НЕВЕРНО\n\nОтвет команды нельзя зачесть, поск...    False
# 4   #НЕВЕРНО\n\nОтвет команды не подходит, посколь...    False
# 5   #ВЕРНО\nРассуждения:\nОтвет команды «Роман» мо...     True
# 6   #НЕВЕРНО\n\nОтвет команды не подходит, потому ...    False
# 7   #НЕВЕРНО\n\nРассуждения: в вопросе говорится, ...    False
# 8   #ВЕРНО\n\nОтвет команды совпадает с правильным...     True
# 9   #НЕВЕРНО\n\n**Рассуждения**: на логотипе ветер...    False
# 10  #ВЕРНО\nРассуждения: ответ команды совпадает с...     True
# 11  #НЕВЕРНО\n\nПравильный ответ «матрёшка» не мож...    False
# 12  #ВЕРНО\n\nРассуждения: ответ команды можно зач...     True
# 13  #ВЕРНО\n\nОтвет команды совпадает с правильным...     True
# 14  #НЕВЕРНО\n\nОтвет команды не подходит по смысл...    False
# 15  #НЕВЕРНО\n\nОтвет команды не подходит по смысл...    False
# 16  #НЕВЕРНО\n\nВ ганской пословице речь идёт о то...    False
# 17  #ВЕРНО\n\nОтвет команды совпадает с правильным...     True
# 18  #НЕВЕРНО\n\nОтвет команды не подходит под опис...    False
# 19  #НЕВЕРНО\n\nОтвет команды «маляр» не подходит ...    False
# 20  #НЕВЕРНО\n\nКоманда дала неверный ответ, так к...    False
# 21  #НЕВЕРНО\n\nКоманда дала ответ 911, который не...    False
# 22  #НЕВЕРНО\nРассуждения: в вопросе идёт речь о н...    False
# 23  #ВЕРНО\n\nОтвет команды можно зачесть, так как...     True
# 24  #НЕВЕРНО\n\nКомпания, продающая сушёные лисичк...    False
# 25  #НЕВЕРНО\n\nЧастица получила название «Шалтай-...    False
# 26  #НЕВЕРНО\nРассуждения: Демокрит — греческий фи...    False
# 27  #НЕВЕРНО\nРассуждения: подгузники и скафандры ...    False
# 28  #НЕВЕРНО\n\nОтвет команды не подходит под вопр...    False
# 29  #НЕВЕРНО\n\nОтвет команды не подходит по смысл...    False
# 30  #НЕВЕРНО\n\nОтвет команды не подходит по смысл...    False
# 31  #ВЕРНО\nРассуждения: Ответ команды «Тень» явля...     True
# 32  #ВЕРНО\nРассуждения: в статье о турецких масте...     True
# 33  #НЕВЕРНО\n\nРассуждения: прозвище Кадваллона —...    False
# 34  #НЕВЕРНО\nРассуждения: Согласно шутке, первым ...    False
# 35  #НЕВЕРНО\n\nОтвет команды «Сердце» не подходит...    False
# 36  #ВЕРНО\n\nОтвет команды «Красная шапка» можно ...     True
# 37  #ВЕРНО\nРассуждения: оба ответа — «летучая мыш...     True
# 38  #ВЕРНО\n\nОтвет команды «Сизиф» можно зачесть,...     True
# 39  #НЕВЕРНО\n\nКоманда дала ответ «Остров огня», ...    False
#
#                                              thoughts  \
# 0   **1–2.** Автор детективов Иэн Рэнкин увлекаетс...
# 1   **Шаг 1.** В вопросе есть такие детали и подск...
# 2   Конечно, я могу помочь вам с этим вопросом. Во...
# 3   Конечно, я могу попытаться найти ответ на этот...
# 4   Хорошо, давайте попробуем ответить на этот воп...
# 5   1 - 2) В этом вопросе могут быть важны следующ...
# 6   1 - 2) В вопросе упоминается стадо, которое ис...
# 7   **1–2.** В вопросе есть такие детали:\n* кораб...
# 8   Конечно, я могу помочь вам с вопросом о Рут Хе...
# 9   1 - 2) В вопросе упоминается определённое круп...
# 10  1 - 2) В вопросе есть такая важная деталь, как...
# 11  Конечно, я могу помочь вам найти ответ на вопр...
# 12  **1–2.** В вопросе идёт речь о сети пекарен, к...
# 13  1. **Важные детали вопроса и потенциальные под...
# 14  1 - 2) В вопросе упоминаются подростки, которы...
# 15  Хорошо, давайте попробуем найти ответ на этот ...
# 16  1 - 2) В ганской пословице говорится о том, чт...
# 17  1 - 2) В этом вопросе могут быть важны следующ...
# 18  Хорошо, я попробую найти ответ на этот вопрос,...
# 19  **1–2.** В вопросе говорится о клиенте, которы...
# 20  1 - 2) В вопросе говорится о сушке дров и о то...
# 21  1–2) В вопросе упоминается социальная реклама,...
# 22  1 - 2) В вопросе упоминается толерантная Польш...
# 23  1. **Важные детали и потенциальные подсказки.*...
# 24  1 - 2) В вопросе упоминается российская компан...
# 25  1-2) В вопросе есть важная деталь — дата откры...
# 26  **1–2.** В вопросе говорится об идее атомов, к...
# 27  **1–2.** В вопросе есть намёк на терминологию ...
# 28  **1-2)** В вопросе есть несколько важных детал...
# 29  1. В вопросе есть намёк на то, что у школьника...
# 30  1 - 2) Я вижу, в вопросе неспроста могут быть:...
# 31  **1–2.** В этом вопросе я вижу следующие детал...
# 32  1 - 2) В вопросе упоминаются турецкие мастериц...
# 33  1 - 2) Кадваллон — легендарный правитель Уэльс...
# 34  **1 - 2)** В вопросе есть подсказка — Португал...
# 35  1 - 2) Историк Фернан Бродель изучал развитие ...
# 36  **1–2.** В вопросе есть несколько деталей, кот...
# 37  **Исидор Севильский называл ЕЁ единственной че...
# 38  **Вопрос: В эмиграции поэт Георгий Адамович ус...
# 39  1 - 2) Новый остров Сюртсей назван в честь пер...
#
#                                          answer_cot  \
# 0                             Сортировка информации
# 1                                             Охота
# 2                                     Исследователь
# 3                                    Давид и Голиаф
# 4                                              Рука
# 5                                            Роман.
# 6                                           Барашки
# 7                                          Капитан.
# 8                                    Личная свобода
# 9                                             БЕЛКА
# 10                                        АСТЕРОИДЫ
# 11                                     Многотиражка
# 12                                     Калорийность
# 13  АльбертЭйнштейн опроверг теорию относительности
# 14                                           Крылья
# 15                                     Конструкция.
# 16                           Пословицы и поговорки.
# 17                                 Навыки и умения.
# 18                                       Библиотека
# 19                                        Вредитель
# 20                                      кошкакорова
# 21                                      Дваразавгод
# 22                                          вешалки
# 23                                             Торт
# 24                                    МихаилПришвин
# 25                                             ЛЕГО
# 26                                 Обычный предмет.
# 27                              Подушки или матрасы
# 28                                     ЯмаутиХироси
# 29                                              УХО
# 30                                           Монета
# 31                                           Отслед
# 32                                        портфолио
# 33                             ВильгельмЗавоеватель
# 34                                         Магеллан
# 35                                         Центрами
# 36                                       Жёлтыйцвет
# 37                                    Летучая мышь.
# 38                                             Поэт
# 39                                    Остров вулкан
#
#                                      answer_cot_check  correct_cot
# 0   #ВЕРНО\n\nОтвет команды «сортировка информации...         True
# 1   Рассуждения:\n\nКоманда дала ответ «Охота», ко...        False
# 2   #НЕВЕРНО\n\nОтвет команды не подходит под конт...        False
# 3   #НЕВЕРНО\n\nВ ответе команды «Давид и Голиаф» ...        False
# 4   #НЕВЕРНО\n\nВ вопросе спрашивают про «ещё одну...        False
# 5   #ВЕРНО\n\nРассуждения:\nОтвет команды соответс...         True
# 6   #ВЕРНО\n\nОтвет команды соответствует правильн...         True
# 7   Рассуждения:\n\nВ вопросе говорится о корабле ...        False
# 8   #НЕВЕРНО\n\nЛичная свобода — это состояние чел...        False
# 9   #НЕВЕРНО\n\nВ ответе команды упоминается белка...        False
# 10  Рассуждения:\n\nВопрос касается возможного поя...        False
# 11  Рассуждения:\nВ контексте вопроса важно, что г...        False
# 12  #ВЕРНО\n\nОтвет команды «Калорийность» можно з...         True
# 13  Рассуждения:\n\nОтвет команды не подходит к во...        False
# 14  Рассуждения:\n\nПерсонаж Джона Грина сравнивае...        False
# 15  #НЕВЕРНО\n\nКонструкция — это общее название р...        False
# 16  **Рассуждения**:\n\nВ ганской пословице говори...        False
# 17  Рассуждения:\n\nПравильный ответ «корочки, кор...        False
# 18  Рассуждения:\n\nКоманда дала ответ «Библиотека...         True
# 19  #НЕВЕРНО\n\nОтвет команды «вредитель» не подхо...        False
# 20  **Рассуждения**:\n\nВ вопросе идёт речь о прав...        False
# 21  Рассуждения:\n\nВ этом вопросе речь идёт об из...        False
# 22  Рассуждения:\n\nВ вопросе спрашивают, без чего...        False
# 23  #НЕВЕРНО\n\nВ контексте вопроса спрашивается, ...        False
# 24  #НЕВЕРНО\n\nВ вопросе спрашивают, в честь како...        False
# 25  Рассуждения:\n\nВопрос касается открытия новой...        False
# 26  Рассуждения:\n\nПравильный ответ указывает на ...        False
# 27  #НЕВЕРНО\n\nХотя в вопросе не уточняется, для ...        False
# 28  #НЕВЕРНО\n\nВ вопросе спрашивают имя итальянск...        False
# 29  **Рассуждения:**\n\nПравильный ответ — «под». ...        False
# 30  **Рассуждения.**\n\nВопрос касается того, что ...        False
# 31  Рассуждения:\n\nОтвет команды «Отслед» не соот...        False
# 32  #НЕВЕРНО\n\nВ статье о турецких мастерицах гов...        False
# 33  Рассуждения:\n\nВопрос касается прозвища Кадва...        False
# 34  #ВЕРНО\n\nВ вопросе спрашивают, кто был первым...         True
# 35  #НЕВЕРНО\n\nВ вопросе требуется одно слово — о...        False
# 36  Рассуждения:\n\nВопрос касается восстания «Кра...        False
# 37  #ВЕРНО\n\nКоманда дала верный ответ, который с...         True
# 38  Рассуждения:\nВопрос касается сравнения поэта ...        False
# 39  Рассуждения:\n\nВопрос касается происхождения ...        False

# %% [markdown]
# # Вычисление итоговой метрики

# %%
def normalize_text(s):
    """Removing articles and punctuation, and standardizing whitespace are all typical text processing steps."""
    import string, re

    def remove_articles(text):
        regex = re.compile(r"\b(a|an|the)\b", re.UNICODE)
        return re.sub(regex, " ", text)

    def white_space_fix(text):
        return " ".join(text.split())

    def remove_punc(text):
        exclude = set(string.punctuation)
        return "".join(ch for ch in text if ch not in exclude)

    def lower(text):
        return text.lower()

    return white_space_fix(remove_articles(remove_punc(lower(s))))

def compute_exact_match(prediction, truth):
    return int(normalize_text(prediction) == normalize_text(truth))

def compute_f1(prediction, truth):
    pred_tokens = normalize_text(prediction).split()
    truth_tokens = normalize_text(truth).split()

    # if either the prediction or the truth is no-answer then f1 = 1 if they agree, 0 otherwise
    if len(pred_tokens) == 0 or len(truth_tokens) == 0:
        return int(pred_tokens == truth_tokens)

    common_tokens = set(pred_tokens) & set(truth_tokens)

    # if there are no common tokens then f1 = 0
    if len(common_tokens) == 0:
        return 0

    prec = len(common_tokens) / len(pred_tokens)
    rec = len(common_tokens) / len(truth_tokens)

    return 2 * (prec * rec) / (prec + rec)

# %%
def metrics_calculation(df):
    df['f1_score']=df.apply(lambda x: compute_f1(x['predict'], x['a']), axis=1)
    df['exact_match']=df.apply(lambda x: compute_exact_match(x['predict'], x['a']), axis=1)
    return df

# %%
test=metrics_calculation(test)
total_f1_score=test['f1_score'].mean()
total_exact_match=test['exact_match'].mean()

# %%
base_string = "Ты профеесиональный игрок в ЧТо? Где? Когда? Я покажу тебе вопрос из Что? Где? Когда? с  правильным ответом к нему. Еще я подам ответ, который дала команда. Тебе нужно СРАВНИТЬ правильный ответ с ответом команды и ответить, можно ли зачесть ответ команды. Выведи свой ответ в таком формате: Сначала рассуждения, почему ты принял это решение. Потом ответ: #ВЕРНО, если ответ можно зачесть или #НЕВЕРНО, если нельзя. "

# %%
from tqdm import tqdm

tqdm.pandas()
def query_gpt_answer(row, prompt=base_string):
    completion = yandex_gpt.get_sync_completion(messages=[{'role': 'user', 'text': prompt+row['q'] + ' Правильный ответ:'+ row['a'] + 'Ответ команды:' + row['predict'] }])
    sleep(0.2)
    return completion
test['answer_checking'] =  test.progress_apply(query_gpt_answer, axis=1)
# Out:
# 100%|██████████| 400/400 [21:46<00:00,  3.27s/it]

# %%
# %pip install asyncio
import asyncio

async def apply_async(df, func):
    loop = asyncio.get_event_loop()
    tasks = [loop.create_task(func(row)) for _, row in df.iterrows()]
    return await asyncio.gather(*tasks)

# %%
test
# Out:
#      Unnamed: 0                                                  q  \
# 485         492  Автор детективов Иэн Рэнкин увлекается неким з...
# 817         828  Некоторые виды мух называют путниками из-за их...
# 30           33  Хави Повес активно продвигает концепцию плоско...
# 551         560  Борющаяся с музыкальными корпорациями группа C...
# 96          100  Голландский шахматист Мануэль Босбом выиграл с...
# ..          ...                                                ...
# 289         294  Василий Рóзанов писал, что Наталья Нóрдман пог...
# 238         243  Математик семнадцатого века Джон ВАллис активн...
# 0             0  В одном из эпизодов мультфильма Криса Батлера ...
# 832         843  В стихотворении под названием «ОН» Дэвид Лоуре...
# 409         416  «Сначала паруса, а потом корпус корабля». Это ...
#
#                                                      a                predict  \
# 485  собирать пазл, собирать мозаику, складывать па...  Раскладывать пасьянс.
# 817                      спутниками, спутники, спутник             расстоянии
# 30                                астронавт, космонавт              Космонавт
# 551                                     троянский конь             Дон Кихот.
# 96                                         дырка, дыра               Надпись.
# ..                                                 ...                    ...
# 289                                            пылесос       Каспийское море.
# 238  курица, куриная лапа, лапа курицы, лапка куриц...             Какофония.
# 0                                        сэр, сир, sir                   Сэр.
# 832                             комары, комар, комарик                   Элли
# 409  шарообразность Земли, Что Земля шар, а также Ч...    Бесконечность мира.
#
#      f1_score  exact_match                                    answer_checking
# 485  0.000000            0  #НЕВЕРНО\n\nИэн Рэнкин увлекается собиранием п...
# 817  0.000000            0  #НЕВЕРНО.\n\nКоманда ответила на вопрос неполн...
# 30   0.666667            0  #ВЕРНО\nОтвет команды «Космонавт» можно зачест...
# 551  0.000000            0  #НЕВЕРНО\n\nОтвет команды нельзя зачесть, поск...
# 96   0.000000            0  #НЕВЕРНО\n\nОтвет команды не подходит, посколь...
# ..        ...          ...                                                ...
# 289  0.000000            0  #НЕВЕРНО\nРассуждения: Василий Розанов сравнив...
# 238  0.000000            0  #НЕВЕРНО\nРассуждения: ответ команды «Какофони...
# 0    0.500000            0  #ВЕРНО\n\nОтвет команды «сэр» можно зачесть, т...
# 832  0.000000            0  #НЕВЕРНО\n\nОтвет команды не подходит, посколь...
# 409  0.000000            0  #НЕВЕРНО\n\nКоманда дала неверный ответ. Прави...
#
# [400 rows x 7 columns]

# %%
test['correct'] = test['answer_checking'].apply(lambda x: '#ВЕРНО' in x)
print(len(test))
test
# Out:
# 400
#      Unnamed: 0                                                  q  \
# 485         492  Автор детективов Иэн Рэнкин увлекается неким з...
# 817         828  Некоторые виды мух называют путниками из-за их...
# 30           33  Хави Повес активно продвигает концепцию плоско...
# 551         560  Борющаяся с музыкальными корпорациями группа C...
# 96          100  Голландский шахматист Мануэль Босбом выиграл с...
# ..          ...                                                ...
# 289         294  Василий Рóзанов писал, что Наталья Нóрдман пог...
# 238         243  Математик семнадцатого века Джон ВАллис активн...
# 0             0  В одном из эпизодов мультфильма Криса Батлера ...
# 832         843  В стихотворении под названием «ОН» Дэвид Лоуре...
# 409         416  «Сначала паруса, а потом корпус корабля». Это ...
#
#                                                      a                predict  \
# 485  собирать пазл, собирать мозаику, складывать па...  Раскладывать пасьянс.
# 817                      спутниками, спутники, спутник             расстоянии
# 30                                астронавт, космонавт              Космонавт
# 551                                     троянский конь             Дон Кихот.
# 96                                         дырка, дыра               Надпись.
# ..                                                 ...                    ...
# 289                                            пылесос       Каспийское море.
# 238  курица, куриная лапа, лапа курицы, лапка куриц...             Какофония.
# 0                                        сэр, сир, sir                   Сэр.
# 832                             комары, комар, комарик                   Элли
# 409  шарообразность Земли, Что Земля шар, а также Ч...    Бесконечность мира.
#
#      f1_score  exact_match                                    answer_checking  \
# 485  0.000000            0  #НЕВЕРНО\n\nИэн Рэнкин увлекается собиранием п...
# 817  0.000000            0  #НЕВЕРНО.\n\nКоманда ответила на вопрос неполн...
# 30   0.666667            0  #ВЕРНО\nОтвет команды «Космонавт» можно зачест...
# 551  0.000000            0  #НЕВЕРНО\n\nОтвет команды нельзя зачесть, поск...
# 96   0.000000            0  #НЕВЕРНО\n\nОтвет команды не подходит, посколь...
# ..        ...          ...                                                ...
# 289  0.000000            0  #НЕВЕРНО\nРассуждения: Василий Розанов сравнив...
# 238  0.000000            0  #НЕВЕРНО\nРассуждения: ответ команды «Какофони...
# 0    0.500000            0  #ВЕРНО\n\nОтвет команды «сэр» можно зачесть, т...
# 832  0.000000            0  #НЕВЕРНО\n\nОтвет команды не подходит, посколь...
# 409  0.000000            0  #НЕВЕРНО\n\nКоманда дала неверный ответ. Прави...
#
#      correct
# 485    False
# 817    False
# 30      True
# 551    False
# 96     False
# ..       ...
# 289    False
# 238    False
# 0       True
# 832    False
# 409    False
#
# [400 rows x 8 columns]

# %%
test.to_csv('test_res_with_bin.csv')

# %%
test['correct_cot'].sum()/ len(test['correct'])
# Out:
# 0.175

# %%
row = test.iloc[27]
print(row)
completion = yandex_gpt.get_sync_completion(messages=[{'role': 'user', 'text': base_string+row['q'] + ' ПРАВИЛЬНЫЙ ответ:'+ row['a'] + 'Ответ команды:' + row['predict'] }])
completion
# Out:
# Unnamed: 0                                                       298
# q                  В терминологии NASA [нáса] ОНИ называются «оде...
# a                                               подгузники, памперсы
# predict                                        космические скафандры
# f1_score                                                         0.0
# exact_match                                                        0
# answer_checking    #НЕВЕРНО\nРассуждения: подгузники и памперсы —...
# correct                                                        False
# Name: 292, dtype: object
# '#НЕВЕРНО\nРассуждения: подгузники и памперсы действительно можно назвать «одеждой с максимальным поглощением» в контексте их основной функции. Однако скафандры NASA также выполняют защитную функцию и могут быть названы «одеждой с максимальным поглощением», так как они должны максимально поглощать воздействие неблагоприятных условий космоса на человека.\n\nОтвет команды «космические скафандры» не может быть засчитан, так как он не является точным ответом на вопрос.'

# %%
row['q']
# Out:
# 'В терминологии NASA [нáса] ОНИ называются «одеждой с максимальным поглощением». Названия самых популярных моделей ИХ переводятся как «баловники» и «обнимашки». Назовите ИХ.'

# %%
df
# Out:
#      Unnamed: 0                                                  q  \
# 0             0  В одном из эпизодов мультфильма Криса Батлера ...
# 1             1  В коротком произведении Елены Кацюбы в аду зло...
# 2             2  По сюжету фильма Дэвида Хьюитта четверо астрон...
# 3             3  Дэвид Вуттон пишет, что раньше одни учёные пол...
# 4             4  Ведущие украинской телепередачи “Орёл и решка”...
# ..          ...                                                ...
# 836         847  Животные рода хрисаора также известны как морс...
# 837         848  Альберто Анджела пишет, что если проследить пе...
# 838         849  В казахских танцах движения рук имеют важную р...
# 839         850  Начало карьеры Линдси Лохан в кино было по-нас...
# 840         851  Казахские девушки традиционно заплетают волосы...
#
#                                                      a
# 0                                        сэр, сир, sir
# 1                                                 удав
# 2                                         Дороти, Элли
# 3    игра Камень ножницы бумага, Камень ножницы бумага
# 4                             Дома лучше, А дома лучше
# ..                                                 ...
# 836                                     Медуса, Медуза
# 837                                             монета
# 838                                   на себя, от себя
# 839            диснеевские принцессы, принцессы Дисней
# 840                                свадьба, замужество
#
# [841 rows x 3 columns]

# %%
total_f1_score
# Out:
# 0.21845238095238093

# %%
total_exact_match
# Out:
# 0.175
